# %%
# !pwd #yolov5아니면 yolov5경로로 들어가기 -> cd yolov5
# Out:
# /abr/coss09/yolov5

# %%
# %pip install -qr requirements.txt      #설치 안 되어 있음 설치, 설치 되어 있음 Note:~라 뜸
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python /abr/coss09/yolov5/train.py --img 3840 --batch 16 --epochs 10 --data /abr/coss09/yolov5/data/custom.yaml --cfg /abr/coss09/yolov5/models/yolov5s.yaml --name please_yolov5s_results
# Out:
# WARNING ⚠️ invalid check_version(3.1.36, ) requested, please check values.
# train: weights=yolov5s.pt, cfg=/abr/coss09/yolov5/models/yolov5s.yaml, data=/abr/coss09/yolov5/data/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=3840, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=please_yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.18 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#
# ...

# %%
# !python /abr/coss09/yolov5/detect.py --weights /abr/coss09/yolov5/runs/train/please_yolov5s_results6/weights/best.pt --img 3840 --conf 0.25 --source /abr/coss09/yolov5/data/images/test --save-txt
# Out:
# detect: weights=['/abr/coss09/yolov5/runs/train/please_yolov5s_results6/weights/best.pt'], source=/abr/coss09/yolov5/data/images/test, data=data/coco128.yaml, imgsz=[3840, 3840], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=True, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.18 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Saving runs/detect/exp5/test1/stage0_Conv_features.png... (32/32)
# Saving runs/detect/exp5/test1/stage1_Conv_features.png... (32/64)
# ...

# %%
from PIL import Image
from IPython.display import display

# 이미지 파일 경로
image_path = '/content/drive/MyDrive/elphin_yolov5/yolov5/runs/detect/exp8/test1.jpg'

# 이미지 표시
display(Image.open(image_path))
